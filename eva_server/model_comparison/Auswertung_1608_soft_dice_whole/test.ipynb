# %%
import pandas as pd

# %%
results = pd.read_csv('all_model_summary.csv')

# %%
results[['model_display','dice_mean', 'rmse_mean', 'rmse_whole_mean', 'soft_dice_whole_mean', 'spot_recognition_mean']]
# Out:
#                                         model_display  dice_mean  rmse_mean  \
# 0                             one-output Dice/L1 loss   0.684306   0.134998
# 1               two-output Tversky loss small dataset   0.729274   0.578302
# 2             multi-output BCE/MSE loss small dataset   0.643873   0.145955
# 3                             two-output Tversky loss   0.962670   0.666420
# 4                           multi-output BCE/MSE loss   0.821373   0.127253
# 5                  two-output L1 loss base channel 32   0.878355   0.064776
# 6                        two-output L1 loss batch 100   0.922220   0.048224
# 7           multi-output Tversky loss base channel 32   0.929444   0.043144
# 8                                  two-output L1 loss   0.915637   0.051014
# 9                      two-output reconstruction loss   0.880010   0.040692
# 10                multi-output Tversky loss batch 100   0.933207   0.041137
# ...
